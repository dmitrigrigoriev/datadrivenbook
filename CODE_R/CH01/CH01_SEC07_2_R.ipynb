# %%
library(dplyr)
# Out:
# Warning message:
# "package 'dplyr' was built under R version 3.6.3"
# Attaching package: 'dplyr'
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union

# %%
# Define a function to show face images ####
showImage <- function(x, m, n) {
  x %>%
  as.numeric() %>%
  matrix(nrow = m, ncol=n) %>%
  apply(2, rev) %>% #Rotate matrix by 90 degrees, step one : reverse columns 
  t %>% # Rotate matrix by 90 degrees, step two: transpose matrix
  image(col=grey(seq(0, 1, length=256)), xaxt="n", yaxt="n") # 256 diffrent intensities between 0 and 1 defined
}

# %%
n = 1000
q = as.numeric(n/4)
X = matrix(1, nrow=n, ncol=n)

X[(q):(3*q),(q):(3*q)] = 2
showImage(X, n, n)
title("Unrotated Matrix")
# Out:
# Plot with title "Unrotated Matrix"

# %%
res = svd(X)

# %%
plot(1:length(res$d), res$d, main="Singular values (log)", xlab="", ylab="Singular Value", log="y", pch=19)
lines(1:length(res$d), res$d)
# Out:
# Plot with title "Singular values (log)"
